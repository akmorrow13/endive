# %%
# %pylab inline
from snakebite.client import Client
import pyaml as yaml
import sys
import pythonrun
reload(pythonrun)
import os
import seaborn as sns
from sklearn import metrics
import scala_python_endive_wrapper
reload(scala_python_endive_wrapper)
from scala_python_endive_wrapper import *
import pandas as pd
import os
from sklearn.cluster import KMeans
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
hdfsclient = Client("amp-spark-master.amp", 8020, use_trash=False)
notebook_stdout = sys.stdout
notebook_stderr = sys.stderr
terminal_stdout = open('/dev/stdout', 'w')
terminal_stderr = open('/dev/stderr', 'w')
logpath = "/tmp/log"

# %%
executor_mem = "200g"
cores_per_executor = 32
num_executors = 14
EGR1_PATH = '/user/vaishaal/endive-data/EGR1'

# %%
make_dnase_gaussian_filter_gen(1.0, 1.0)(100).shape
# Out:
# (100, 232)

# %%
# this is where the magic happens
results = [] 
num_filters = [256, 512, 4096, 8192]
gammas = [1.0]
dnase_gammas = [1.0]
kmer_size = 8
dnase_kmer_sizes = [100]

# %%
chromosomes = map(lambda x: "chr{0}".format(x+1), range(23))
# CHANGE ME BASED ON ENUM + TF
egr1_cell_types = string_to_enum_celltypes(['GM12878', 'H1hESC', 'HCT116', 'MCF7'])

for gamma in gammas:
    for dnase_gamma in dnase_gammas:
        for dnase_kmer_size in dnase_kmer_sizes:
            for num_filter in num_filters:
                feat_out_loc = "/user/vaishaal/featurizedWindows/sequence/tiny/{0}-filters/{1}-gamma/{2}-dnase-gamma/{3}-kmers/{4}-dnase-kmers/replicate-0"\
                  .format(num_filter, gamma, dnase_gamma, kmer_size, dnase_kmer_size)
                res = run_kitchensink_featurize_pipeline(EGR1_PATH,
                           "/tmp/filters.csv", 
                           logpath, 
                           seed=0,
                           cores_per_executor=cores_per_executor,
                           sample=0.01,
                           alphabet_size=4,
                           kmer_size=kmer_size,
                           dnase_kmer_size=dnase_kmer_size,
                           gamma=gamma,
                           dnase_gamma=dnase_gamma,
                           executor_mem=executor_mem,
                           num_filters=num_filter,
                           num_partitions=cores_per_executor*num_executors,
                           featuresOutput=feat_out_loc,
                           num_executors=num_executors)
# Out:
# W SHAPE  (256, 232)
# {'kmerLength': 8, 'reference': '/home/eecs/akmorrow/ADAM/endive/workfiles/hg19.2bit', 'filtersPath': '/tmp/filters.csv', 'numPartitions': 448, 'dnaseBams': '/data/anv/DREAMDATA/dnase_bams/merged_coverage/', 'approxDim': 256, 'aggregatedSequenceOutput': '/user/vaishaal/endive-data/EGR1', 'featuresOutput': '/user/vaishaal/featurizedWindows/sequence/tiny/256-filters/1.0-gamma/1.0-dnase-gamma/8-kmers/100-dnase-kmers/replicate-0', 'seed': 0, 'dnaseNarrow': '/data/anv/DREAMDATA/DNASE/peaks/relaxed/', 'dnaseKmerLength': 100, 'featurizeSample': 0.01, 'alphabetSize': 4, 'readFiltersFromDisk': True}

# %%
results_dfs = []
for gamma in gammas:
    for dnase_gamma in dnase_gammas:
        for dnase_kmer_size in dnase_kmer_sizes:
            for num_filter in num_filters:    
                print (gamma, dnase_gamma, dnase_kmer_size, num_filter)
                meta = {}
                meta['num_filter'] = num_filter
                meta['dnase_kmer_size'] = dnase_kmer_size
                meta['dnase_gamma'] = dnase_gamma
                meta['gamma'] = gamma
                results_df = cross_validate(feat_out_loc, 
                            hdfsclient, 
                            chromosomes, 
                            egr1_cell_types,
                            numHoldOutChr=1, 
                            numHoldOutCell=1,
                            cores_per_executor = 32,
                            num_executors = 14,
                            executor_mem="150g",
                            num_folds=1, 
                            negativeSamplingFreqs=[0.001],
                            regs=[1e-8],
                            other_meta=meta)
                print(results_df)
                results_dfs.append(results_df)
# Out:
# (1.0, 1.0, 100, 256)
# FOLD 0
# HOLDING OUT CHROMOSOMES ['chr12']
# HOLDING OUT CELL TYPES [3]
# RUNING SOLVER WITH REG=1e-08
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-150-73f95e2280dd> in <module>()
#      22                             negativeSamplingFreqs=[0.001],
#      23                             regs=[1e-8],
# ---> 24                             other_meta=meta)
#      25                 print(results_df)
#      26                 results_dfs.append(results_df)
#
# /home/eecs/vaishaal/endive/python/scala_python_endive_wrapper.py in cross_validate(feature_path, hdfsclient, chromosomes, cellTypes, numHoldOutChr, numHoldOutCell, num_folds, regs, negativeSamplingFreqs, seed, executor_mem, cores_per_executor, num_executors, other_meta)
#     334                            valCellTypes=[8],
#     335                            valChromosomes=["chr10"],
# --> 336                            valDuringSolve=True)
#     337
#     338             train_metrics = compute_metrics(train_res[:, 1], train_res[:, 0], tag='train')
#
# /home/eecs/vaishaal/endive/python/scala_python_endive_wrapper.py in run_solver_pipeline(featuresPath, logpath, hdfsclient, cores_per_executor, num_executors, executor_mem, use_yarn, valChromosomes, valCellTypes, reg, negativeSamplingFreq, predictionsPath, valDuringSolve, modelPath, base_config)
#     136               cores_per_executor,
#     137               num_executors,
# --> 138               use_yarn=True)
#     139
#     140     if valDuringSolve:
#
# /home/eecs/vaishaal/endive/python/pythonrun.pyc in run(config, logpath, pipelineClass, pipelineJar, KEYSTONE_MEM, SPARK_EXECUTOR_CORES, SPARK_NUM_EXECUTORS, OMP_NUM_THREADS, output_sanity_check, use_yarn)
#      85
#      86     if p.returncode != 0:
# ---> 87         raise Exception("invocation terminated with non-zero exit status")
#      88
#      89     time_log_fid = open(time_log, 'w')
#
# Exception: invocation terminated with non-zero exit status

# %%
results_df
# Out:
#    dnase_gamma  dnase_kmer_size  gamma  negativeSamplingFreq  num_filter  \
# 0            1              100      1                   0.1        4096
#
#             reg test_celltypes test_chromosomes  train_auPRC  train_auROC  \
# 0  1.000000e-08            [3]          [chr12]     0.758994     0.976533
#
#    train_recall_at_05_fdr  train_recall_at_10_fdr  train_recall_at_25_fdr  \
# 0                0.540177                0.574641                0.658865
#
#    train_recall_at_50_fdr  val_auPRC  val_auROC  val_recall_at_05_fdr  \
# 0                0.779211   0.066275   0.867573                     0
#
#    val_recall_at_10_fdr  val_recall_at_25_fdr  val_recall_at_50_fdr
# 0                     0                     0              0.020408

# %%
results_df = cross_validate("/user/akmorrow/featurized/wavelets/EGR1_dnase_all_dim_256", 
                            hdfsclient, 
                            chromosomes, 
                            egr1_cell_types,
                            numHoldOutChr=1, 
                            numHoldOutCell=1,
                            cores_per_executor = 32,
                            num_executors = 14,
                            executor_mem="150g",
                            num_folds=1, 
                            negativeSamplingFreqs=[0.01],
                            regs=[1000])
# Out:
# FOLD 0
# HOLDING OUT CHROMOSOMES ['chr12']
# HOLDING OUT CELL TYPES [3]
# RUNING SOLVER WITH REG=1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-154-658827d43610> in <module>()
#      11                             num_folds=1,
#      12                             negativeSamplingFreqs=[0.01],
# ---> 13                             regs=[1000])
#      14
#
# /home/eecs/vaishaal/endive/python/scala_python_endive_wrapper.py in cross_validate(feature_path, hdfsclient, chromosomes, cellTypes, numHoldOutChr, numHoldOutCell, num_folds, regs, negativeSamplingFreqs, seed, executor_mem, cores_per_executor, num_executors, other_meta)
#     334                            valCellTypes=[8],
#     335                            valChromosomes=["chr10"],
# --> 336                            valDuringSolve=True)
#     337
#     338             train_metrics = compute_metrics(train_res[:, 1], train_res[:, 0], tag='train')
#
# /home/eecs/vaishaal/endive/python/scala_python_endive_wrapper.py in run_solver_pipeline(featuresPath, logpath, hdfsclient, cores_per_executor, num_executors, executor_mem, use_yarn, valChromosomes, valCellTypes, reg, negativeSamplingFreq, predictionsPath, valDuringSolve, modelPath, base_config)
#     136               cores_per_executor,
#     137               num_executors,
# --> 138               use_yarn=True)
#     139
#     140     if valDuringSolve:
#
# /home/eecs/vaishaal/endive/python/pythonrun.pyc in run(config, logpath, pipelineClass, pipelineJar, KEYSTONE_MEM, SPARK_EXECUTOR_CORES, SPARK_NUM_EXECUTORS, OMP_NUM_THREADS, output_sanity_check, use_yarn)
#      82                          shell=True, executable='/bin/bash',
#      83                          env = env)
# ---> 84     p.wait()
#      85
#      86     if p.returncode != 0:
#
# /home/eecs/vaishaal/anaconda2/lib/python2.7/subprocess.pyc in wait(self)
#    1390             while self.returncode is None:
#    1391                 try:
# -> 1392                     pid, sts = _eintr_retry_call(os.waitpid, self.pid, 0)
#    1393                 except OSError as e:
#    1394                     if e.errno != errno.ECHILD:
#
# /home/eecs/vaishaal/anaconda2/lib/python2.7/subprocess.pyc in _eintr_retry_call(func, *args)
#     474     while True:
#     475         try:
# --> 476             return func(*args)
#     477         except (OSError, IOError) as e:
#     478             if e.errno == errno.EINTR:
#
# KeyboardInterrupt:

# %%
3results_df
# Out:
#    negativeSamplingFreq   reg test_celltypes test_chromosomes  train_auPRC  \
# 0                  0.01  1000            [3]          [chr12]     0.358819
#
#    train_auROC  train_recall_at_05_fdr  train_recall_at_10_fdr  \
# 0     0.958541                0.018828                0.026998
#
#    train_recall_at_25_fdr  train_recall_at_50_fdr  val_auPRC  val_auROC  \
# 0                0.065364                0.291297   0.148956   0.925958
#
#    val_recall_at_05_fdr  val_recall_at_10_fdr  val_recall_at_25_fdr  \
# 0              0.074074              0.074074              0.074074
#
#    val_recall_at_50_fdr
# 0              0.074074

# %%
# Out:
# 0.88036847526310447

# %%
feat_out_loc
# Out:
# '/user/vaishaal/featurizedWindows/sequence/tiny/256-filters/1.0-gamma/1.0-dnase-gamma/8-kmers/100-dnase-kmers/replicate-0'

# %%
old_result_dfs = pd.concat(results_dfs)

# %%
old_result_dfs
# Out:
#    dnase_gamma  dnase_kmer_size  gamma  negativeSamplingFreq           reg  \
# 0            1                8    0.1                     1  1.000000e-08
# 0            1               16    0.1                     1  1.000000e-08
# 0            1               32    0.1                     1  1.000000e-08
# 0            1                8    0.1                     1  1.000000e-08
# 0            1               16    0.1                     1  1.000000e-08
# 0            1               32    0.1                     1  1.000000e-08
# 0            1                8    0.1                     1  1.000000e-08
# 0            1               16    0.1                     1  1.000000e-08
# 0            1               32    0.1                     1  1.000000e-08
# 0            1                8    1.0                     1  1.000000e-08
# 0            1               16    1.0                     1  1.000000e-08
# 0            1               32    1.0                     1  1.000000e-08
# 0            1                8    1.0                     1  1.000000e-08
# 0            1               16    1.0                     1  1.000000e-08
# 0            1               32    1.0                     1  1.000000e-08
# 0            1                8    1.0                     1  1.000000e-08
# 0            1               16    1.0                     1  1.000000e-08
# 0            1               32    1.0                     1  1.000000e-08
# 0            1                8   10.0                     1  1.000000e-08
